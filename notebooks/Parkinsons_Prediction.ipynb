# %% [markdown]
# <a href="https://colab.research.google.com/github/Infant-Joshva/Data-Science-learning-path/blob/main/Project_4(Multiple_Disease_Prediction)/notebooks/Parkinsons_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset-2 (Parkinsons Prediction) - Data Preprocessing

# %% [markdown]
# #### Importing Necessary Packages for Data Cleaning

# %%
import pandas as pd

# %%
sheet_id= '1GQ2wltXJ-veItC2BVoWJx7MmeS2mcljb62dVRrAMYZk'
sheet_name = "sheet1"

#https://docs.google.com/spreadsheets/d/1GQ2wltXJ-veItC2BVoWJx7MmeS2mcljb62dVRrAMYZk/edit?gid=630750312#gid=630750312

url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

parkinsons_df = pd.read_csv(url)

# %%
parkinsons_df
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
parkinsons_df['Disease_Status'] = parkinsons_df['status'].map({1:'Yes', 0:'No'})

# %% [markdown]
# ####Data Type conversion

# %%
parkinsons_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
# All datatypes are correct no need to alter

# %% [markdown]
# ####Handling Null Values

# %%
parkinsons_df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# Disease_Status      0
# dtype: int64

# %%
# There is no null values

# %% [markdown]
# ####Deleting Duplicate Values

# %%
# Deleting not needed columns

parkinsons_df.drop(['name'], axis=1, inplace=True)

# %% [markdown]
# ####Deleting Duplicate Values

# %%
parkinsons_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# There is no duplicates

# %% [markdown]
# ### EDA Process - For Features Selection

# %% [markdown]
# **The major types of analysis you’ll typically do in data preprocessing for ML, it’s mainly:**
#
#
#
# ---
#
#
# 1. Univariate Analysis
# * One variable at a time.
#
# * Purpose: Understand distribution, central tendency, spread, and outliers.
#
#
# ---
#
#
# 2. Bivariate Analysis
# * Two variables at a time.
#
# * Purpose: Find relationships, correlations, and trends.
#
#
# ---
#
#
# 3. Multivariate Analysis
# * Three or more variables together.
#
# * Purpose: Detect combined effects, interactions, patterns, and multicollinearity.
#
#
# ---
#
#
# 4. Missing Value Analysis
# * Purpose: Identify and handle missing or incomplete data.
#
#
# ---
#
#
# 5. Outlier Analysis
# * Purpose: Detect and decide how to treat extreme/unusual values.
#
#
# ---
#
#
# 6. Correlation Analysis
# * Purpose: Measure relationship strength, avoid redundant features.
#
#
# ---
#
#
# 7. Class Imbalance Analysis (for classification problems)
# * Purpose: Check if target variable has uneven distribution.

# %% [markdown]
# #### Importing Necessary Packages for EDA

# %%
# For plots
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
# For Stats
import numpy as np
import scipy.stats as stats
from scipy.stats import ttest_ind

# %% [markdown]
# #### Univarient Analysis

# %%
parkinsons_df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
parkinsons_df.describe().T
# Out:
#                   count        mean        std         min         25%  \
# MDVP:Fo(Hz)       195.0  154.228641  41.390065   88.333000  117.572000
# MDVP:Fhi(Hz)      195.0  197.104918  91.491548  102.145000  134.862500
# MDVP:Flo(Hz)      195.0  116.324631  43.521413   65.476000   84.291000
# MDVP:Jitter(%)    195.0    0.006220   0.004848    0.001680    0.003460
# MDVP:Jitter(Abs)  195.0    0.000044   0.000035    0.000007    0.000020
# MDVP:RAP          195.0    0.003306   0.002968    0.000680    0.001660
# MDVP:PPQ          195.0    0.003446   0.002759    0.000920    0.001860
# Jitter:DDP        195.0    0.009920   0.008903    0.002040    0.004985
# MDVP:Shimmer      195.0    0.029709   0.018857    0.009540    0.016505
# MDVP:Shimmer(dB)  195.0    0.282251   0.194877    0.085000    0.148500
# Shimmer:APQ3      195.0    0.015664   0.010153    0.004550    0.008245
# Shimmer:APQ5      195.0    0.017878   0.012024    0.005700    0.009580
# ...

# %%
parkinsons_df['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
parkinsons_df.columns
# Out:
# Index(['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE', 'Disease_Status'],
#       dtype='object')

# %%
parkinsons_df.head(10)
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
# 5      120.552       131.162       113.787         0.00968           0.00008
# 6      120.267       137.244       114.820         0.00333           0.00003
# 7      107.332       113.840       104.315         0.00290           0.00003
# 8       95.730       132.068        91.754         0.00551           0.00006
# 9       95.056       120.103        91.226         0.00532           0.00006
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# ...

# %%
# Checking the distribution of each column

for col in parkinsons_df.columns:
  fig1 = px.box(parkinsons_df, x=col, title=f'{col} Box plot')
  fig1.show()
  print('-'*200)
  fig2 = px.histogram(parkinsons_df, x=col, title=f'{col} Distribution')
  fig2.show()
  print('-'*200)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Bivarient Analysis

# %% [markdown]
# *   Our target is status

# %%
parkinsons_df.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2   0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3   0.00502   0.00698     0.01505       0.05492             0.517  ...
# 4   0.00655   0.00908     0.01966       0.06425             0.584  ...
#
# ...

# %%
# sns.pairplot(parkinsons_df, hue='status')

# %%
parkinsons_df['Disease_Status']=parkinsons_df['status'].map({1:'Yes', 0:'No'})

# %%
parkinsons_df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %% [markdown]
# #### Num vs Cat(Target)

# %% [markdown]
# *   Target = Disease_Status

# %%
num_df = parkinsons_df.select_dtypes(include=['int64', 'float64'])
num_df.drop('status', axis=1, inplace=True)
num_df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
for col in num_df.columns:
  fig = px.box(parkinsons_df, x='Disease_Status', y=col, title=f'{col} vs Disease Status')
  fig1 = px.histogram(parkinsons_df, x='Disease_Status', y=col, title=f'{col} vs Disease Status Distribution')
  fig.show()
  fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### Doing Hypothesis Test for require column

# %%
#Hypothesis test

for col in num_df.columns:

  # class A and B scores
  class_a = parkinsons_df[parkinsons_df['Disease_Status']=='Yes'][col]
  class_b = parkinsons_df[parkinsons_df['Disease_Status']=='No'][col]

  # Perform two-sample t-test (assume equal variances)
  t_statistic, p_value = stats.ttest_ind(class_a, class_b)

  # Print the results
  print("T-statistic:", t_statistic)
  print("P-value:", p_value)

  # Interpretation
  alpha = 0.05  # significance level
  if p_value < alpha:
    print(f"Reject the null hypothesis. There is a significant difference in {col} between Disease_Status (Yes) and Disease_Status (No).")
    print('-'*150)
  else:
    print(f"Fail to reject the null hypothesis. There is no significant difference in {col} between Disease_Status (Yes) and Disease_Status (No).")
    print('-'*150)
# Out:
# T-statistic: -5.769452074779698
# P-value: 3.1219194028363605e-08
# Reject the null hypothesis. There is a significant difference in MDVP:Fo(Hz) between Disease_Status (Yes) and Disease_Status (No).
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# T-statistic: -2.3405672508312865
# P-value: 0.020275669142798675
# Reject the null hypothesis. There is a significant difference in MDVP:Fhi(Hz) between Disease_Status (Yes) and Disease_Status (No).
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# T-statistic: -5.71076835971258
# P-value: 4.1970041821534524e-08
# Reject the null hypothesis. There is a significant difference in MDVP:Flo(Hz) between Disease_Status (Yes) and Disease_Status (No).
# ...

# %% [markdown]
# **Therefore all colums are required for prediction**

# %% [markdown]
# ## ML - Model selection and Traning

# %% [markdown]
# ### Importing necessary packages

# %%
# Data preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN

# %%
# Machine learning models
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier

# Evaluation metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Importing lib for Pipeline

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,OrdinalEncoder,OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
# Databalancing

from imblearn.pipeline import Pipeline as IMBPipeline
from imblearn.over_sampling import SMOTE, ADASYN

# %% [markdown]
# ### Train, Test Split and Scaling, Encoding

# %%
X = parkinsons_df.drop(['Disease_Status', 'status'], axis=1)
Y = parkinsons_df['Disease_Status']

# %%
# There is no cat column so we can directly use x and y

# %%
parkinsons_df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
X_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])
X_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('scaler', StandardScaler())])

# %%
X.columns
# Out:
# Index(['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA', 'spread1',
#        'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
# Combining the transformer as a full loaded pipeline with column transformer

preprocess = ColumnTransformer([
    ('num', X_pipeline, X.columns)
])
preprocess
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA', 'spread1',
#        'spread2', 'D2', 'PPE'],
#       dtype='object'))])

# %% [markdown]
# #### ML - Pipeline

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ##### LogReg

# %%
# Creating pipeline for LogReg

logreg_pipeline = IMBPipeline([
    ('preprocess', preprocess),
    ('Sampling',SMOTE(random_state=42)),
    ('Poly',PolynomialFeatures(degree=2)),
    ('logreg', LogisticRegression(class_weight="balanced",penalty='l2'))
])

logreg_pipeline.fit(X_train, Y_train)

Y_train_pred = logreg_pipeline.predict(X_train)
Y_test_pred = logreg_pipeline.predict(X_test)

print('Confusion Matrix Train')
print('--'*50)
print(confusion_matrix(Y_train,Y_train_pred))
print('Confusion Matrix Test')
print('--'*50)
print(confusion_matrix(Y_test,Y_test_pred))
print('**'*50)
print('Classification Report Train')
print('--'*50)
print(classification_report(Y_train,Y_train_pred))
print('Classification Report Test')
print('--'*50)
print(classification_report(Y_test,Y_test_pred))
print('--'*50)
# Out:
# Confusion Matrix Train
# ----------------------------------------------------------------------------------------------------
# [[ 41   0]
#  [  1 114]]
# Confusion Matrix Test
# ----------------------------------------------------------------------------------------------------
# [[ 4  3]
#  [ 1 31]]
# ****************************************************************************************************
# Classification Report Train
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#           No       0.98      1.00      0.99        41
#          Yes       1.00      0.99      1.00       115
#
#     accuracy                           0.99       156
#    macro avg       0.99      1.00      0.99       156
# weighted avg       0.99      0.99      0.99       156
#
# Classification Report Test
# ...

# %% [markdown]
# ##### Random Forest

# %%
# Creating pipeline for Random Forest

rf_pipeline = IMBPipeline([
    ('preprocess', preprocess),
    ('Poly',PolynomialFeatures(degree=2)),
    ('rf', RandomForestClassifier(criterion="entropy",max_depth=5,min_samples_split=10,min_samples_leaf=5,random_state=42))
])

rf_pipeline.fit(X_train, Y_train)

Y_train_pred = rf_pipeline.predict(X_train)
Y_test_pred = rf_pipeline.predict(X_test)

print('Confusion Matrix Train')
print('--'*50)
print(confusion_matrix(Y_train,Y_train_pred))
print('Confusion Matrix Test')
print('--'*50)
print(confusion_matrix(Y_test,Y_test_pred))
print('**'*50)
print('Classification Report Train')
print('--'*50)
print(classification_report(Y_train,Y_train_pred))
print('Classification Report Test')
print('--'*50)
print(classification_report(Y_test,Y_test_pred))
print('--'*50)
# Out:
# Confusion Matrix Train
# ----------------------------------------------------------------------------------------------------
# [[ 38   3]
#  [  1 114]]
# Confusion Matrix Test
# ----------------------------------------------------------------------------------------------------
# [[ 5  2]
#  [ 0 32]]
# ****************************************************************************************************
# Classification Report Train
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#           No       0.97      0.93      0.95        41
#          Yes       0.97      0.99      0.98       115
#
#     accuracy                           0.97       156
#    macro avg       0.97      0.96      0.97       156
# weighted avg       0.97      0.97      0.97       156
#
# Classification Report Test
# ...

# %% [markdown]
# ###### Exporting the selected pipeline

# %%
import pickle

# %%
pickle.dump(rf_pipeline, open('rf_pipeline.pkl', 'wb'))

# %%
# Creating pipeline for Random Forest

rf_pipeline = IMBPipeline([
    ('preprocess', preprocess),
    ('Poly',PolynomialFeatures(degree=2)),
    ('rf', RandomForestClassifier(criterion="entropy",
    max_depth=4,              # reduced depth
    min_samples_split=10,
    min_samples_leaf=5,
    n_estimators=200,         # smaller forest to reduce overfit
    random_state=42))
])

rf_pipeline.fit(X_train, Y_train)

Y_train_pred = rf_pipeline.predict(X_train)
Y_test_pred = rf_pipeline.predict(X_test)

print('Confusion Matrix Train')
print('--'*50)
print(confusion_matrix(Y_train,Y_train_pred))
print('Confusion Matrix Test')
print('--'*50)
print(confusion_matrix(Y_test,Y_test_pred))
print('**'*50)
print('Classification Report Train')
print('--'*50)
print(classification_report(Y_train,Y_train_pred))
print('Classification Report Test')
print('--'*50)
print(classification_report(Y_test,Y_test_pred))
print('--'*50)
# Out:
# Confusion Matrix Train
# ----------------------------------------------------------------------------------------------------
# [[ 37   4]
#  [  1 114]]
# Confusion Matrix Test
# ----------------------------------------------------------------------------------------------------
# [[ 4  3]
#  [ 0 32]]
# ****************************************************************************************************
# Classification Report Train
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#           No       0.97      0.90      0.94        41
#          Yes       0.97      0.99      0.98       115
#
#     accuracy                           0.97       156
#    macro avg       0.97      0.95      0.96       156
# weighted avg       0.97      0.97      0.97       156
#
# Classification Report Test
# ...

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold

# Stratified K-Fold (preserves class balance)
skf = StratifiedKFold(n_splits=6, shuffle=True, random_state=42)

# Model
rf = RandomForestClassifier(random_state=42)

# Cross-validation scores (accuracy here)
scores = cross_val_score(rf, X, Y, cv=skf, scoring='accuracy')

print("Cross-validation scores:", scores)
print("Mean Accuracy:", scores.mean())
# Out:
# Cross-validation scores: [0.96969697 0.93939394 0.93939394 0.90625    0.875      0.78125   ]
# Mean Accuracy: 0.9018308080808081
